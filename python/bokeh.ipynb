# %% [markdown]
# # Python - `bokeh`

# %%
from bokeh.plotting import figure
from bokeh.charts import Area, Line, output_notebook, show
from bokeh.models import Plot, BoxAnnotation, Label, Span, ColumnDataSource, DataRange1d
from bokeh.models.glyphs import Patch

import numpy
import pandas
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="21902dde-7509-4ed8-8b78-fd312cbc9a79">Loading BokehJS ...</span>
#     </div>

# %%
temp = pandas.read_csv("../HadCRUT4-gl-dowload20170601.csv", sep = ";")
temp = temp.assign(Min = [min(temp[temp.columns[1:13]].loc[i]) for i in range(temp.shape[0])],
                   Max = [max(temp[temp.columns[1:13]].loc[i]) for i in range(temp.shape[0])])
# temp.head()

# %%
p = figure(plot_width = 800, plot_height = 500, y_axis_label = "Temperature anomaly")

p.add_layout(Span(location = 0, dimension = 'width', line_color='#999999', line_dash='dashed'))
p.add_layout(BoxAnnotation(left = 1961, right = 1990, fill_color = '#dddddd'))
p.add_layout(Label(x = 1961, y = min(temp.Min), text = 'Reference period', text_font_size = "10pt"))

source = ColumnDataSource(dict(x = numpy.append(temp.Year, temp.Year[::-1]), 
                               y = numpy.append(temp.Min, temp.Max[::-1])))
glyph = Patch(x="x", y="y", fill_color="lightblue", line_color = "lightblue")
p.add_glyph(source, glyph)

p.line(temp.Year, y = temp.Annual, color = "steelblue")


show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c971f376-8a52-4ddd-8390-0f2770f3defc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c971f376-8a52-4ddd-8390-0f2770f3defc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c971f376-8a52-4ddd-8390-0f2770f3defc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c971f376-8a52-4ddd-8390-0f2770f3defc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cca08703-5a10-413c-b429-8c9d96f10b99":{"roots":{"references":[{"attributes":{"callback":null},"id":"74165795-63e2-4c0b-a3d8-0baebd80341a","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"3f0d4142-0d19-43a9-bbf0-b107744dd80b","subtype":"Figure","type":"Plot"},"ticker":{"id":"b4b04aa0-8c5f-47b4-90c4-670ca045bda4","type":"BasicTicker"}},"id":"498f0df6-a264-4bc9-93e5-b494669134bc","type":"Grid"},{"attributes":{"data_source":{"id":"dc2699b8-c770-4966-9601-f05676e5eaa0","type":"ColumnDataSource"},"glyph":{"id":"b55a78fa-ac38-4646-a53e-47e7f8412abe","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"20cd7b9b-9af7-42d1-8272-da37c9a14d89","type":"Line"},"selection_glyph":null},"id":"7d00af8a-2ef0-4aea-be2a-adb56ccb92c3","type":"GlyphRenderer"},{"attributes":{},"id":"4f77ffb9-5d50-4145-b2bb-1b85ff13c26d","type":"BasicTicker"},{"attributes":{"plot":{"id":"3f0d4142-0d19-43a9-bbf0-b107744dd80b","subtype":"Figure","type":"Plot"},"text":"Reference period","text_font_size":{"value":"10pt"},"x":1961,"y":-0.9590000000000001},"id":"b0749f57-3122-4907-9c08-902fa9d1bbd7","type":"Label"},{"attributes":{"plot":{"id":"3f0d4142-0d19-43a9-bbf0-b107744dd80b","subtype":"Figure","type":"Plot"}},"id":"f3cccdf1-3add-45dd-839d-9f1686b9317e","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"448f8307-6244-49d0-a90c-a667c2520f65","type":"BasicTickFormatter"},"plot":{"id":"3f0d4142-0d19-43a9-bbf0-b107744dd80b","subtype":"Figure","type":"Plot"},"ticker":{"id":"4f77ffb9-5d50-4145-b2bb-1b85ff13c26d","type":"BasicTicker"}},"id":"2a800216-83b4-4e88-a7d1-a88c6fd854f3","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#999999"},"line_dash":[6],"location":0,"plot":{"id":"3f0d4142-0d19-43a9-bbf0-b107744dd80b","subtype":"Figure","type":"Plot"}},"id":"17cef6ae-be13-460a-a84a-faeab422a575","type":"Span"},{"attributes":{},"id":"b4b04aa0-8c5f-47b4-90c4-670ca045bda4","type":"BasicTicker"},{"attributes":{},"id":"96d57af9-2c4a-4bcf-b73e-59ae30071939","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"#dddddd"},"left":1961,"plot":{"id":"3f0d4142-0d19-43a9-bbf0-b107744dd80b","subtype":"Figure","type":"Plot"},"right":1990},"id":"3f0e1733-bf54-46dc-a757-c2bf287abdff","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"3f0d4142-0d19-43a9-bbf0-b107744dd80b","subtype":"Figure","type":"Plot"}},"id":"264b5951-d260-4608-af5e-bb7816c3ddd5","type":"SaveTool"},{"attributes":{"plot":{"id":"3f0d4142-0d19-43a9-bbf0-b107744dd80b","subtype":"Figure","type":"Plot"}},"id":"e2640440-1c7d-425b-b3aa-0923f7dc02d1","type":"ResetTool"},{"attributes":{"data_source":{"id":"d0442009-759e-44fc-bd76-3849ecb68548","type":"ColumnDataSource"},"glyph":{"id":"3bada508-24e0-4be3-95dd-bc3d26571312","type":"Patch"},"hover_glyph":null,"muted_glyph":null},"id":"4019fdac-d36f-4fc0-9956-1123e109e6ec","type":"GlyphRenderer"},{"attributes":{"axis_label":"Temperature anomaly","formatter":{"id":"96d57af9-2c4a-4bcf-b73e-59ae30071939","type":"BasicTickFormatter"},"plot":{"id":"3f0d4142-0d19-43a9-bbf0-b107744dd80b","subtype":"Figure","type":"Plot"},"ticker":{"id":"b4b04aa0-8c5f-47b4-90c4-670ca045bda4","type":"BasicTicker"}},"id":"670ab628-53b0-4ad5-a753-7c553983fb9c","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1850,1851,1852,1853,1854,1855,1856,1857,1858,1859,1860,1861,1862,1863,1864,1865,1866,1867,1868,1869,1870,1871,1872,1873,1874,1875,1876,1877,1878,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,19 ...
